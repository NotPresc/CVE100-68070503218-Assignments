# %%
class car: 
    def __init__(self, model, rent_per_day, available):
        self.model = model
        self.rent_per_day = rent_per_day
        self.available = True
    def rent(self,days):
        if self.available == True:
            self.available = False
            Total_cost = self.rent_per_day * days
            print("Total_cost", Total_cost)
        else:
            print("Car not available")
        
    def return_car(self):
        self.available = True
        print("Car Returned")
    def display(self):
        print("model",self.model)
        print("rent_per_day",self.rent_per_day)
        print("available",self.available)

# %%
car_1 = car("Volvo EX90",900, True)
car_1.rent(5)
car_1.display()
car_1.return_car()
car_1.display()
# Out:
# Total_cost 4500
# model Volvo EX90
# rent_per_day 900
# available False
# Car Returned
# model Volvo EX90
# rent_per_day 900
# available True

# %%
class Person:
    def __init__(self,name, age):
        self.name = name
        self.age = age
    def display(self):
        print("name", name)
        print("age", age)
class student(Person):
    def __init__(self,name,age):
        super().__init__(name,age)
        self.marks = {}
    def add_mark(self, subjects, score):
        if subjects not in self.marks:
            self.marks[subjects] = score
            print(f"Add a new {subjects}")
        else :
            old_score = self.marks[subjects]
            self.mark[subjects] = score
            print("Updated the score of the subject")
            print("old score", old_score)
            print("new score", score)
    def display_mark(self):
        if not self.marks:
            return 0
        for subject,score in self.marks.items():
            print(f"{subject}:,{score}")
    def average(self):
        if  len(self,marks) == 0:
            return 0
        else:
            return 
        avg = sum(self.marks.value())/sum(self.marks)
        print(avg)

# %%
std1=student("pong",12)
std1.add_mark("English",99)
std1.add_mark("Math",99)
std1.display_mark()
# Out:
# Add a new English
# Add a new Math
# English:,99
# Math:,99
